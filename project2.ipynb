# %% [markdown]
# # Project 2: Web Scraping and API access

# %%
# !pip install beautifulsoup4

# %% [markdown]
# ## Part 1: Explore the html for Wikipedia articles.

# %% [markdown]
# ### A. Using inspect element, copy the html code for a table.
# <table class="infobox ib-video-game hproduct"><tbody><tr><th colspan="2" class="infobox-above fn">Hollow Knight</th></tr><tr><td colspan="2" class="infobox-image"><span class="mw-default-size" typeof="mw:File/Frameless"><a href="/wiki/File:Hollow_Knight_first_cover_art.webp" class="mw-file-description"><img src="//upload.wikimedia.org/wikipedia/en/thumb/0/04/Hollow_Knight_first_cover_art.webp/220px-Hollow_Knight_first_cover_art.webp.png" decoding="async" width="220" height="292" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/04/Hollow_Knight_first_cover_art.webp/274px-Hollow_Knight_first_cover_art.webp.png 1.5x" data-file-width="274" data-file-height="364"></a></span></td></tr><tr><th scope="row" class="infobox-label"><a href="/wiki/Video_game_developer" title="Video game developer">Developer(s)</a></th><td class="infobox-data">Team Cherry</td></tr><tr><th scope="row" class="infobox-label"><a href="/wiki/Video_game_publisher" title="Video game publisher">Publisher(s)</a></th><td class="infobox-data">Team Cherry</td></tr><tr><th scope="row" class="infobox-label"><a href="/wiki/Video_game_designer" class="mw-redirect" title="Video game designer">Designer(s)</a></th><td class="infobox-data"><style data-mw-deduplicate="TemplateStyles:r1126788409">.mw-parser-output .plainlist ol,.mw-parser-output .plainlist ul{line-height:inherit;list-style:none;margin:0;padding:0}.mw-parser-output .plainlist ol li,.mw-parser-output .plainlist ul li{margin-bottom:0}</style><div class="plainlist"><ul><li>Ari Gibson</li><li>William Pellen</li></ul></div></td></tr><tr><th scope="row" class="infobox-label"><a href="/wiki/Video_game_programmer" title="Video game programmer">Programmer(s)</a></th><td class="infobox-data"><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r1126788409"><div class="plainlist"><ul><li>William Pellen</li><li>David Kazi</li></ul></div></td></tr><tr><th scope="row" class="infobox-label"><a href="/wiki/Video_game_artist" class="mw-redirect" title="Video game artist">Artist(s)</a></th><td class="infobox-data">Ari Gibson</td></tr><tr><th scope="row" class="infobox-label"><a href="/wiki/Video_game_composer" class="mw-redirect" title="Video game composer">Composer(s)</a></th><td class="infobox-data"><a href="/wiki/Christopher_Larkin_(composer)" title="Christopher Larkin (composer)">Christopher Larkin</a></td></tr><tr><th scope="row" class="infobox-label"><a href="/wiki/Game_engine" title="Game engine">Engine</a></th><td class="infobox-data"><a href="/wiki/Unity_(game_engine)" title="Unity (game engine)">Unity</a></td></tr><tr><th scope="row" class="infobox-label"><a href="/wiki/Computing_platform" title="Computing platform">Platform(s)</a></th><td class="infobox-data"><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r1126788409"><div class="plainlist"><ul><li><a href="/wiki/Windows" class="mw-redirect" title="Windows">Windows</a></li><li><a href="/wiki/Linux" title="Linux">Linux</a></li><li><a href="/wiki/MacOS" title="MacOS">macOS</a></li><li><a href="/wiki/Nintendo_Switch" title="Nintendo Switch">Nintendo Switch</a></li><li><a href="/wiki/PlayStation_4" title="PlayStation 4">PlayStation 4</a></li><li><a href="/wiki/Xbox_One" title="Xbox One">Xbox One</a></li></ul></div></td></tr><tr><th scope="row" class="infobox-label">Release</th><td class="infobox-data"><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r1126788409"><div class="plainlist"><ul><li><b>Windows</b></li><li>24 February 2017</li><li><b>Linux</b>, <b>macOS</b></li><li>11 April 2017</li><li><b>Nintendo Switch</b></li><li>12 June 2018</li><li><b>PlayStation 4</b>, <b>Xbox One</b></li><li>25 September 2018</li></ul></div></td></tr><tr><th scope="row" class="infobox-label"><a href="/wiki/Video_game_genre" title="Video game genre">Genre(s)</a></th><td class="infobox-data"><a href="/wiki/Metroidvania" title="Metroidvania">Metroidvania</a></td></tr><tr><th scope="row" class="infobox-label">Mode(s)</th><td class="infobox-data"><a href="/wiki/Single-player" class="mw-redirect" title="Single-player">Single-player</a></td></tr></tbody></table>

# %% [markdown]
# ### B. Using inspect element, find the html syntax for a link.
# <a href="/wiki/Hollow_Knight" title="View the content page [alt-shift-c]" accesskey="c"><span>Article</span></a>

# %% [markdown]
# ### C. Using inspect element, find the html syntax for linking an image
# <img src="//upload.wikimedia.org/wikipedia/en/thumb/0/04/Hollow_Knight_first_cover_art.webp/220px-Hollow_Knight_first_cover_art.webp.png" decoding="async" width="220" height="292" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/04/Hollow_Knight_first_cover_art.webp/274px-Hollow_Knight_first_cover_art.webp.png 1.5x" data-file-width="274" data-file-height="364">

# %% [markdown]
# ## Part 2: Explore one Wikipedia page with the beautifulsoup package

# %%
import bs4 
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
#save and print the text content of a page with all tags removed 
source = requests.get('https://en.wikipedia.org/wiki/Hollow_Knight').text 
soup = BeautifulSoup(source) 
print(soup.get_text())
# Out:
# Hollow Knight - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Donate
#
#
#
#
#
#
#
#
# Appearance
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Create account
#
# Log in
#
#
#
#
#
#
#
#
# Personal tools
#
#
#
#
#
#  Create account Log in
#
#
#
#
#
# 		Pages for logged out editors learn more
#
#
#
# ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# (Top)
#
#
#
#
#
# 1
# Gameplay
#
#
#
#
#
#
#
#
# 2
# Plot
#
#
#
#
# Toggle Plot subsection
#
#
#
#
#
# 2.1
# The Grimm Troupe expansion
#
#
#
#
#
#
#
#
# 2.2
# ...

# %%
#download an image with beautifulsoup and save it in this repository 
img_tags=soup.find_all('img') 
img_url='https:' + img_tags[5]['src']
img=requests.get(img_url)
with open('image.jpg','wb') as f:
    f.write(img.content)

# %%
#find all the links in a page with beautifulsoup
#print the first 100 characters of ten of these links 
links = soup.find_all('a') 
for i in range(1, 10):
    print(links[i].get('href')[:100])
# Out:
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal

# %% [markdown]
# ## Part 3: Downloading scripts

# %%
scripts=pd.read_csv('pudding_data.csv')

# %%
scripts
# Out:
#         imdb_id  script_id             title  year  \
# 0     tt0019777       4031     The Cocoanuts  1929
# 1     tt0021884       8521      Frankenstein  1931
# 2     tt0022054       1086   The Last Flight  1931
# 3     tt0022626       1631  American Madness  1932
# 4     tt0022958       2438       Grand Hotel  1932
# ...         ...        ...               ...   ...
# 1995  tt3733778       8533     Pay the Ghost  2015
# 1996  tt3808342       5499       Son of Saul  2015
# 1997  tt3850214       8056              Dope  2015
# 1998  tt3859076       5507             Truth  2015
# 1999  tt4270516       5410           Grandma  2015
#
#       gross (inflation-adjusted)  \
# 0                            NaN
# 1                          298.0
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1995                         NaN
# 1996                         0.0
# 1997                        18.0
# ...

# %%
def clean(text):

    #convert the text to lowercase
    text = text.lower()
    #remove punctuation
    text = ''.join([char for char in text if char.isalpha() or char.isspace()])
    #remove newline and space characters
    text = ' '.join(text.split())
    return text

# %%
# using the links in the "link" column, download the first 1000 characters of each script
# use requests and bs4, remember to remove all html tags 
script_texts = []
for i in range(len(scripts)):
    try:
        source = requests.get(scripts['link'][i]).text
        soup = BeautifulSoup(source)
        intros = soup.get_text()[:1000]
        script_texts.append(clean(intros))
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {scripts['link'][i]}: {e}")
        script_texts.append("")

df = pd.DataFrame({'script': script_texts})
df
# Out:
# Error fetching http://www.pages.drexel.edu/~ina22/splaylib/Screenplay-Cocoanuts,_The.pdf: HTTPConnectionPool(host='www.pages.drexel.edu', port=80): Max retries exceeded with url: /~ina22/splaylib/Screenplay-Cocoanuts,_The.pdf (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x000001AE6C6D9160>: Failed to resolve 'www.pages.drexel.edu' ([Errno 11001] getaddrinfo failed)"))
# Error fetching Frankenstein (Florey & Fort) [1931-5-23] [Scan].pdf: Failed to parse: Frankenstein (Florey & Fort) [1931-5-23] [Scan].pdf
# Error fetching film_20100519/all_imsdb_05_19_10/Last-Flight,-The.html: Invalid URL 'film_20100519/all_imsdb_05_19_10/Last-Flight,-The.html': No scheme supplied. Perhaps you meant https://film_20100519/all_imsdb_05_19_10/Last-Flight,-The.html?
# ...

# %%
#add a new column to the df with the text downloaded
#save this new dataframe as "pudding_texts.csv" 
df.to_csv('pudding_texts.csv', index=False)

# %%
import time

# %% [markdown]
# ## Part 4: TMDB database

# %% [markdown]
# #### Browse the documentation at https://developer.themoviedb.org/reference/intro/getting-started. Create an account to authenticate

# %%
#create a dataset of the movies in theaters now. Include metadata fields you are interested in. 

api_key = 'e239bf6b8ebe6b7890af687d1eeece5f'  
url = f'https://api.themoviedb.org/3/movie/now_playing?api_key={api_key}&language=en-US&page=1'
response = requests.get(url).json()
movies = response['results']

# Extracting relevant metadata fields
movie_data = []
for movie in movies:
    movie_data.append({
        'title': movie['title'],
        'release_date': movie['release_date'],
        'vote_average': movie['vote_average'],
        'overview': movie['overview'] 
        }) 
    time.sleep(1)

# Creating a DataFrame
movies_df = pd.DataFrame(movie_data) 
movies_df
# Out:
#                       title release_date  vote_average  \
# 0             Speak No Evil   2024-09-11         7.350
# 1             The Substance   2024-09-07         7.300
# 2                     Wolfs   2024-09-20         6.594
# 3       Joker: Folie à Deux   2024-10-01         5.836
# 4                  The Crow   2024-08-21         5.446
# 5           Project Silence   2024-07-11         7.074
# 6            The Wild Robot   2024-09-12         8.000
# 7            Kill 'em All 2   2024-09-24         6.970
# 8   Beetlejuice Beetlejuice   2024-09-04         7.090
# 9           It Ends with Us   2024-08-07         7.019
# 10                    Joker   2019-10-01         8.154
# 11              Hijack 1971   2024-06-21         5.878
# 12            Hounds of War   2024-08-29         6.453
# 13         Transformers One   2024-09-11         7.374
# 14              Borderlands   2024-08-07         5.885
# 15              Amber Alert   2024-09-27         5.600
# ...

# %%
#download the movie posters for 10 of these movies and save them to this repository  
for i in range(10):
    movie = movies[i]
    poster_url = f"https://image.tmdb.org/t/p/original{movie['poster_path']}"
    poster = requests.get(poster_url)
    with open(f"poster_{i}.jpg", 'wb') as f:
        f.write(poster.content)
    time.sleep(1)
